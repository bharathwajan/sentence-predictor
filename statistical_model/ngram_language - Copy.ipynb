# %% [markdown]
# ## reuters
# The Reuters Corpus contains 10,788 news documents totaling 1.3 million words. The documents have been classified into 90 topics, and grouped into two sets, called "training" and "test"; thus, the text with fileid 'test/14826' is a document drawn from the test set. This split is for training and testing algorithms that automatically detect the topic of a document, as we will see in chap-data-intensive.

# %%
from nltk.corpus import reuters
# len(reuters.fileids())
# reuters.fileids() #gets each file

# %%
type(reuters.words('test/14826'))
# Out:
# nltk.corpus.reader.util.StreamBackedCorpusView

# %% [markdown]
# #### calculating no. of grams

# %%
from collections import defaultdict
from nltk import ngrams
from funcy import flatten, isa

unigram=defaultdict(int)
bigram=defaultdict(int)
trigram=defaultdict(int)
fourgram=defaultdict(int)
fivegram=defaultdict(int)

def gram_calc(sentence,gram):
    if gram==1:
        temp=list(ngrams(sentence,gram))
        for gram in temp:
            unigram[gram]+=1
        return unigram
    elif gram==2:
        temp=list(ngrams(sentence,gram))
        for gram in temp:
            bigram[gram]+=1
        return bigram
    elif gram==3:
        temp=list(ngrams(sentence,gram))
        for gram in temp:
            trigram[gram]+=1
        return trigram
    elif gram==4:
        temp=list(ngrams(sentence,gram))
        for gram in temp:
            fourgram[gram]+=1
        return fourgram
    elif gram==5:
        temp=list(ngrams(sentence,gram))
        for gram in temp:
            fivegram[gram]+=1
        return fivegram

def start_stop_adder(news):
    sentence=[]
    temp=[]
    for word in news:
        # print(word)
        if word!=".":
            temp.append(word)
        elif word==" ":
            continue
        else:
            try:
                temp[0]="<s>"
                temp[len(temp)-1]="</s>"
            except IndexError:
                pass
            sentence.append([" ".join(temp)])
            temp=[]
    return sentence

for news in reuters.fileids():
    lowered_news = [each_string.lower() for each_string in reuters.words(news)]
    sentences=start_stop_adder(lowered_news)
    # print(sentences)
    para=[]
    for sentence in sentences:
        para.append(sentence[0].split(" "))
    # print("para",para)
    para = list(flatten(para))
    # print(para)
    gram_calc(para,1)
    gram_calc(para,2)
    gram_calc(para,3)
    gram_calc(para,4)
    gram_calc(para,5)

# %% [markdown]
# #### calculating probabilities

# %%
uni_count=0
for key,value in unigram.items():
    uni_count+=value
print(uni_count)

bi_count=0
for key,value in bigram.items():
    bi_count+=value
print(bi_count)

tri_count=0
for key,value in trigram.items():
    tri_count+=value
print(tri_count)

four_count=0
for key,value in fourgram.items():
    four_count+=value
print(four_count)

five_count=0
for key,value in fivegram.items():
    five_count+=value
print(five_count)
# Out:
# 1569202
# 1559452
# 1549702
# 1539961
# 1530223

# %% [markdown]
# #### conditional probability : <br>
# Bigram   : p(b|a)=p(a∩b)/p(a)<br>
# trigram  : P(A| B,C) =P(A∩B∩C) /P(B∩C)<br>
# fourgram : P(A| B,C,D) =P(A∩B∩C∩D) /P(B∩C∩D)<br>
# fivegram : P(A| B,C,D,E) =P(A∩B∩C∩D∩E) /P(B∩C∩D∩E)<br>

# %%
uniprob=defaultdict(int)
for key, value in unigram.items():
    new_value = value/uni_count
    uniprob[key] = new_value

# %%
biprob=defaultdict(int)
for key, value in bigram.items():
    temp=[]
    temp.append(f'{key[1]}')
    temp=tuple(temp)
    prob_val=value/unigram[temp]
    biprob[key]=prob_val

# %%
triprob=defaultdict(int)
for key, value in trigram.items():
    temp=key[1:3]
    prob_val=value/bigram[temp]
    triprob[key]=prob_val

# %%
fourprob=defaultdict(int)
for key,value in fourgram.items():
    temp=key[1:4]
    prob_val=value/trigram[temp]
    fourprob[key]=prob_val
# four_prob

# %%
fiveprob=defaultdict(int)
for key,value in fivegram.items():
    temp=key[1:5]
    prob_val=value/fourgram[temp]
    fiveprob[key]=prob_val
# four_prob

# %%
biprob
# Out:
# defaultdict(int,
#             {('<s>', 'exporters'): 0.07303370786516854,
#              ('exporters', 'fear'): 0.0392156862745098,
#              ('fear', 'damage'): 0.008264462809917356,
#              ('damage', 'from'): 0.0009963880931622867,
#              ('from', '</s>'): 0.016529012906360236,
#              ('</s>', '<s>'): 0.8958338152629022,
#              ('<s>', '.-'): 0.9090909090909091,
#              ('.-', 'japan'): 0.014464168310322156,
#              ('japan', 'rift'): 0.5,
#              ('rift', 'mounting'): 0.045454545454545456,
#              ('mounting', 'trade'): 0.0011152416356877324,
#              ('trade', 'friction'): 0.5555555555555556,
#              ('friction', 'between'): 0.0037914691943127963,
#              ('between', 'the'): 0.0039314566295638904,
#              ('the', '</s>'): 0.04859424177774022,
#              ('</s>', '</s>'): 0.07898016518451237,
#              ('<s>', 'japan'): 0.04339250493096647,
#              ('japan', 'has'): 0.009009009009009009,
#              ('has', 'raised'): 0.06744868035190615,
#              ('raised', 'fears'): 0.0547945205479452,
#              ('fears', 'among'): 0.004273504273504274,
#              ('among', 'many'): 0.006535947712418301,
#              ('many', 'of'): 0.0008576329331046312,
#              ('of', 'asia'): 0.04838709677419355,
#              ('asia', "'"): 0.0003615982643283312,
#              ("'", 's'): 0.985172809856949,
#              ('s', 'exporting'): 0.014492753623188406,
#              ('exporting', 'nations'): 0.010554089709762533,
#              ('nations', 'that'): 0.001229172357279432,
#              ('that', 'the'): 0.022079193139027585,
#              ('the', 'row'): 0.061855670103092786,
#              ('row', 'could'): 0.000693000693000693,
#              ('could', 'inflict'): 1.0,
#              ('inflict', 'far'): 0.0031446540880503146,
#              ('far', '-'): 0.00023428348301444748,
#              ('-', 'reaching'): 0.05405405405405406,
#              ('reaching', 'economic'): 0.0010438413361169101,
#              ('economic', 'damage'): 0.008264462809917356,
#              ('damage', ','): 0.00014679330035377184,
#              (',', 'businessmen'): 0.08,
#              ('businessmen', 'and'): 0.00023982732432648493,
#              ('and', 'officials'): 0.01278772378516624,
#              ('officials', '</s>'): 0.002196827274455546,
#              ('<s>', 'told'): 0.1898376852505293,
#              ('told', 'reuter'): 0.08333333333333333,
#              ('reuter', 'correspondents'): 0.8,
#              ('correspondents', 'in'): 3.6429872495446266e-05,
#              ('in', 'asian'): 0.08928571428571429,
#              ('asian', 'capitals'): 0.14285714285714285,
#              ('capitals', 'a'): 4.1937513105472846e-05,
#              ('a', '</s>'): 0.017014849707441753,
#              ('<s>', 'against'): 0.02861035422343324,
#              ('against', 'japan'): 0.03155818540433925,
#              ('japan', 'might'): 0.012626262626262626,
#              ('might', 'boost'): 0.00904977375565611,
#              ('boost', 'protectionist'): 0.011494252873563218,
#              ('protectionist', 'sentiment'): 0.21666666666666667,
#              ('sentiment', 'in'): 0.000692167577413479,
#              ('in', 'the'): 0.10737687241842642,
#              ('<s>', 'lead'): 0.03065134099616858,
#              ('lead', 'to'): 0.0033166563606723256,
#              ('to', 'curbs'): 0.023255813953488372,
#              ('curbs', 'on'): 0.002360876897133221,
#              ('on', 'american'): 0.00980392156862745,
#              ('american', 'imports'): 0.0025031289111389237,
#              ('imports', 'of'): 0.003070879212084325,
#              ('of', 'their'): 0.10052122114668652,
#              ('their', '</s>'): 0.0011512219851714158,
#              ('<s>', 'some'): 0.03135048231511254,
#              ('some', 'exporters'): 0.02247191011235955,
#              ('exporters', 'said'): 0.0003477051460361613,
#              ('said', 'that'): 0.11199125921879267,
#              ('that', 'while'): 0.061224489795918366,
#              ('while', 'the'): 0.002554617387986663,
#              ('the', 'conflict'): 0.10344827586206896,
#              ('conflict', 'would'): 0.00021668472372697725,
#              ('would', 'hurt'): 0.17567567567567569,
#              ('hurt', 'them'): 0.0029154518950437317,
#              ('them', 'in'): 0.0005100182149362477,
#              ('the', 'long'): 0.13087248322147652,
#              ('long', '-'): 0.016477938305349472,
#              ('-', 'run'): 0.23140495867768596,
#              ('run', ','): 7.339665017688592e-05,
#              (',', 'in'): 0.02087431693989071,
#              ('the', 'short'): 0.11136363636363636,
#              ('short', '-'): 0.01483795392424834,
#              ('-', 'term'): 0.6052227342549923,
#              ('term', 'tokyo'): 0.004273504273504274,
#              ('tokyo', "'"): 0.0017175917555595733,
#              ('s', 'loss'): 0.0015840687938447613,
#              ('loss', 'might'): 0.0025252525252525255,
#              ('might', 'be'): 0.019476372924648787,
#              ('be', 'their'): 0.0007446016381236039,
#              ('<s>', '</s>'): 0.030364800067594684,
#              ('<s>', 'said'): 0.2640820584144645,
#              ('said', 'it'): 0.4383998241565007,
#              ('it', 'will'): 0.10543403964456596,
#              ('will', 'impose'): 0.06756756756756757,
#              ('impose', '300'): 0.002386634844868735,
#              ('300', 'mln'): 0.007304771291089338,
#              ('mln', 'dlrs'): 0.33965698955638596,
#              ('dlrs', 'of'): 0.008023017761301389,
#              ('of', 'tariffs'): 0.029661016949152543,
#              ('tariffs', 'on'): 0.007195053400786959,
#              ('on', 'imports'): 0.03754693366708386,
#              ('of', 'japanese'): 0.06614349775784753,
#              ('japanese', 'electronics'): 0.05982905982905983,
#              ('electronics', 'goods'): 0.011594202898550725,
#              ('goods', 'on'): 0.0005621135469364812,
#              ('on', 'april'): 0.13439787092481703,
#              ('april', '17'): 0.08398950131233596,
#              ('17', ','): 0.0011156290826886662,
#              ('in', 'retaliation'): 0.2761904761904762,
#              ('retaliation', 'for'): 0.0025026543303503716,
#              ('for', 'japan'): 0.0210387902695595,
#              ('japan', "'"): 0.024046284577834025,
#              ('s', 'alleged'): 0.22,
#              ('alleged', 'failure'): 0.10185185185185185,
#              ('failure', 'to'): 0.0014053628646916634,
#              ('to', 'stick'): 0.5454545454545454,
#              ('stick', 'to'): 0.00036539434481983247,
#              ('to', 'a'): 0.042734325854476826,
#              ('a', 'pact'): 0.04594594594594595,
#              ('pact', 'not'): 0.00023326335432703523,
#              ('not', 'to'): 0.005256057113946821,
#              ('to', 'sell'): 0.7561307901907357,
#              ('sell', 'semiconductors'): 0.02127659574468085,
#              ('semiconductors', 'on'): 0.0003372681281618887,
#              ('on', 'world'): 0.026581118240146653,
#              ('world', 'markets'): 0.06116207951070336,
#              ('markets', 'at'): 0.0011862396204033216,
#              ('at', 'below'): 0.03260869565217391,
#              ('below', '</s>'): 0.00026404173971821465,
#              ('<s>', 'japanese'): 0.06390134529147982,
#              ('japanese', 'estimates'): 0.004329004329004329,
#              ('estimates', 'put'): 0.022364217252396165,
#              ('put', 'the'): 0.0007630675314765357,
#              ('the', 'impact'): 0.2669491525423729,
#              ('impact', 'of'): 0.002157915122005201,
#              ('of', 'the'): 0.11232022294842658,
#              ('the', 'tariffs'): 0.13559322033898305,
#              ('tariffs', 'at'): 0.0001482799525504152,
#              ('at', '10'): 0.04461538461538461,
#              ('10', 'billion'): 0.004245108896271687,
#              ('billion', 'dlrs'): 0.1330842196033343,
#              ('dlrs', 'and'): 0.0156287473019426,
#              ('and', 'spokesmen'): 0.06666666666666667,
#              ('spokesmen', 'for'): 0.0003033520400424693,
#              ('for', 'major'): 0.026371308016877638,
#              ('major', 'electronics'): 0.017094017094017096,
#              ('electronics', 'firms'): 0.010380622837370242,
#              ('firms', 'said'): 0.0004636068613815484,
#              ('said', 'they'): 0.18296677585400092,
#              ('they', 'would'): 0.02361863488624052,
#              ('would', 'virtually'): 0.021739130434782608,
#              ('virtually', 'halt'): 0.0196078431372549,
#              ('halt', 'exports'): 0.0009643201542912247,
#              ('exports', 'of'): 0.0017705970231837547,
#              ('of', 'products'): 0.027142857142857142,
#              ('products', 'hit'): 0.004672897196261682,
#              ('hit', 'by'): 0.009919493962047153,
#              ('by', 'the'): 0.02554617387986663,
#              ('the', 'new'): 0.21099496709252807,
#              ('new', '</s>'): 0.0016687437950191166,
#              ('<s>', 'we'): 0.3460231135282121,
#              ('we', 'wouldn'): 0.17647058823529413,
#              ('wouldn', "'"): 0.0015367926233954077,
#              ("'", 't'): 0.8912037037037037,
#              ('t', 'be'): 0.00351213282247765,
#              ('be', 'able'): 0.6329113924050633,
#              ('able', 'to'): 0.004356624880544157,
#              ('to', 'do'): 0.27927927927927926,
#              ('do', 'business'): 0.010362694300518135,
#              ('business', ',"'): 0.0038348082595870206,
#              (',"', 'said'): 0.033785350023180345,
#              ('said', 'a'): 0.012581253931641853,
#              ('a', 'spokesman'): 0.13906581740976645,
#              ('spokesman', 'for'): 0.01046564538146519,
#              ('for', 'leading'): 0.004310344827586207,
#              ('leading', 'japanese'): 0.0033632286995515697,
#              ('electronics', 'firm'): 0.01171875,
#              ('firm', 'matsushita'): 0.3333333333333333,
#              ('matsushita', 'electric'): 0.022058823529411766,
#              ('electric', 'industrial'): 0.005235602094240838,
#              ('industrial', 'co'): 0.0018126888217522659,
#              ('co', 'ltd'): 0.11419753086419752,
#              ('ltd', '&'): 0.03961924363262156,
#              ('&', 'lt'): 0.9619625820840044,
#              ('lt', ';'): 0.9916431117119331,
#              (';', '</s>'): 0.015969244418157624,
#              ('<s>', '>.'): 0.1625,
#              ('>.', '"'): 0.004154682007031001,
#              ('"', 'if'): 0.022123893805309734,
#              ('if', 'the'): 0.00625383607318813,
#              ('tariffs', 'remain'): 0.006514657980456026,
#              ('remain', 'in'): 0.0010564663023679417,
#              ('in', 'place'): 0.18562874251497005,
#              ('place', 'for'): 0.0004550280600637039,
#              ('for', 'any'): 0.04104903078677309,
#              ('any', 'length'): 0.14285714285714285,
#              ('length', 'of'): 0.0002766557848724617,
#              ('of', 'time'): 0.03021978021978022,
#              ('time', 'beyond'): 0.02127659574468085,
#              ('beyond', 'a'): 8.387502621094569e-05,
#              ('a', 'few'): 0.30434782608695654,
#              ('few', 'months'): 0.04009163802978236,
#              ('months', 'it'): 0.00043960874821408945,
#              ('will', 'mean'): 0.0898876404494382,
#              ('mean', 'the'): 0.00028200321815437186,
#              ('the', 'complete'): 0.024390243902439025,
#              ('complete', 'erosion'): 0.15384615384615385,
#              ('erosion', 'of'): 0.00022132462789796933,
#              ('of', 'exports'): 0.03278688524590164,
#              ('exports', '('): 0.00038153376573826786,
#              ('(', 'of'): 0.0005809771482321696,
#              ('of', 'goods'): 0.1072463768115942,
#              ('goods', 'subject'): 0.0027100271002710027,
#              ('subject', 'to'): 0.009612681994490977,
#              ('to', 'tariffs'): 0.00847457627118644,
#              ('tariffs', ')'): 0.0010482180293501049,
#              (')', 'to'): 0.0019394007532744955,
#              ('to', 'the'): 0.040824112933994655,
#              ('<s>', '.,"'): 0.9166666666666666,
#              ('.,"', 'said'): 0.0002318034306907742,
#              ('said', 'tom'): 0.3125,
#              ('tom', 'murtha'): 0.8,
#              ('murtha', ','): 2.935866007075437e-05,
#              (',', 'a'): 0.06408052002516251,
#              ('a', 'stock'): 0.0210951526032316,
#              ('stock', 'analyst'): 0.0031645569620253164,
#              ('analyst', 'at'): 0.0050415183867141165,
#              ('at', 'the'): 0.02045352752849062,
#              ('the', 'tokyo'): 0.1111111111111111,
#              ('tokyo', 'office'): 0.004524886877828055,
#              ('office', 'of'): 0.0005533115697449233,
#              ('of', 'broker'): 0.017543859649122806,
#              ('broker', '&'): 0.0009004373552868536,
#              (';', 'james'): 0.011049723756906077,
#              ('james', 'capel'): 0.6666666666666666,
#              ('capel', 'and'): 0.00047965464865296986,
#              ('and', 'co'): 0.16978851963746225,
#              ('co', '>.'): 0.03125,
#              ('>.', 'in'): 0.00029143897996357013,
#              ('in', 'taiwan'): 0.016597510373443983,
#              ('taiwan', ','): 0.0003082659307429209,
#              ('officials', 'are'): 0.004438807863031071,
#              ('are', 'also'): 0.021121039805036556,
#              ('also', '</s>'): 0.0003274117572505862,
#              ('we', 'are'): 0.06404565630944832,
#              ('are', 'aware'): 0.07692307692307693,
#              ('aware', 'of'): 0.0008023017761301388,
#              ('the', 'seriousness'): 1.0,
#              ('seriousness', 'of'): 8.299673546173851e-05,
#              ('japan', 'because'): 0.004812319538017324,
#              ('because', 'it'): 0.011649631827673371,
#              ('it', 'serves'): 0.08,
#              ('serves', 'as'): 0.0007009345794392523,
#              ('as', 'a'): 0.027804571188928498,
#              ('a', 'warning'): 0.16216216216216217,
#              ('warning', 'to'): 0.00022485805835066613,
#              ('to', 'us'): 0.08092485549132948,
#              ('us', ',"'): 0.0032448377581120944,
#              ('a', 'senior'): 0.29296875,
#              ('senior', 'taiwanese'): 0.06666666666666667,
#              ('taiwanese', 'trade'): 0.0007434944237918215,
#              ('trade', 'official'): 0.019474196689386564,
#              ('official', 'who'): 0.019801980198019802,
#              ('who', 'asked'): 0.15254237288135594,
#              ('asked', 'not'): 0.010030324236062515,
#              ('to', 'be'): 0.2539910600255428,
#              ('be', '</s>'): 0.003495912633869162,
#              ('<s>', 'had'): 0.056198910081743866,
#              ('had', 'a'): 0.005913189347871671,
#              ('a', 'trade'): 0.03680297397769517,
#              ('trade', 'trade'): 0.0007434944237918215,
#              ('trade', 'surplus'): 0.31981981981981983,
#              ('surplus', 'of'): 0.002102583965030709,
#              ('of', '</s>'): 0.038222682241608755,
#              ('<s>', 'billion'): 0.8004798818752307,
#              ('dlrs', 'last'): 0.03074380165289256,
#              ('last', 'year'): 0.1490752551020408,
#              ('year', ','): 0.013255435021945598,
#              (',', '95'): 0.04716981132075472,
#              ('95', 'pct'): 0.003427396321261282,
#              ('pct', 'of'): 0.0433242959110275,
#              ('of', 'it'): 0.003626772172766238,
#              ('it', 'with'): 0.003471074380165289,
#              ('with', 'the'): 0.023854154570940398,
#              ('<s>', 'surplus'): 0.03153153153153153,
#              ('surplus', 'helped'): 0.008928571428571428,
#              ('helped', 'swell'): 0.5,
#              ('swell', 'taiwan'): 0.004149377593360996,
#              ('taiwan', "'"): 0.0057855722292533,
#              ('s', 'foreign'): 0.05571847507331378,
#              ('foreign', 'exchange'): 0.20950468540829986,
#              ('exchange', 'reserves'): 0.06043956043956044,
#              ('reserves', 'to'): 0.0013772556073978301,
#              ('to', '53'): 0.045871559633027525,
#              ('53', 'billion'): 0.0011074197120708748,
#              ('dlrs', ','): 0.01940607430676864,
#              (',', 'among'): 0.11965811965811966,
#              ('among', 'the'): 0.0008128328052684836,
#              ('the', 'world'): 0.32997250229147573,
#              ('world', "'"): 0.011661544024588681,
#              ('s', '</s>'): 0.006537673475422995,
#              ('we', 'must'): 0.08157099697885196,
#              ('must', 'quickly'): 0.02247191011235955,
#              ('quickly', 'open'): 0.0025575447570332483,
#              ('open', 'our'): 0.0021141649048625794,
#              ('our', 'markets'): 0.0015290519877675841,
#              ('markets', ','): 0.0014385743434669643,
#              (',', 'remove'): 0.11627906976744186,
#              ('remove', 'trade'): 0.0003717472118959108,
#              ('trade', 'barriers'): 0.29310344827586204,
#              ('barriers', 'and'): 0.0002797985450475658,
#              ('and', 'cut'): 0.026467203682393557,
#              ('cut', 'import'): 0.014742014742014743,
#              ('import', 'tariffs'): 0.038135593220338986,
#              ('tariffs', 'to'): 0.00019675080105683288,
#              ('to', 'allow'): 0.3674418604651163,
#              ('allow', 'imports'): 0.0025031289111389237,
#              ('<s>', ','): 0.026525549373926573,
#              (',', 'if'): 0.07964601769911504,
#              ('if', 'we'): 0.04010876954452753,
#              ('we', 'want'): 0.11330049261083744,
#              ('want', 'to'): 0.0034290853898476586,
#              ('to', 'defuse'): 1.0,
#              ('defuse', 'problems'): 0.004347826086956522,
#              ('problems', 'from'): 0.00012454851164528583,
#              ('from', 'possible'): 0.0055248618784530384,
#              ('possible', '</s>'): 0.00022179506136330032,
#              ('<s>', ',"'): 0.0038348082595870206,
#              ('said', 'paul'): 0.06896551724137931,
#              ('paul', 'sheen'): 1.0,
#              ('sheen', ','): 1.4679330035377185e-05,
#              (',', 'chairman'): 0.189873417721519,
#              ('chairman', 'of'): 0.00426049908703591,
#              ('of', 'textile'): 0.018518518518518517,
#              ('textile', 'exporters'): 0.0056179775280898875,
#              ('exporters', '&'): 0.00012863390789812196,
#              (';', 'taiwan'): 0.004149377593360996,
#              ('taiwan', 'safe'): 0.09090909090909091,
#              ('safe', 'group'): 0.0005213764337851929,
#              ('group', '>.'): 0.003125,
#              ('>.', 'a'): 0.0004193751310547285,
#              ('senior', 'official'): 0.016553067185978577,
#              ('official', 'of'): 0.00047031483428318485,
#              ('of', 'south'): 0.070446735395189,
#              ('south', 'korea'): 0.645320197044335,
#              ('korea', "'"): 0.0039775809076116435,
#              ('s', 'trade'): 0.03940520446096654,
#              ('trade', 'promotion'): 0.045454545454545456,
#              ('promotion', 'association'): 0.0025906735751295338,
#              ('association', 'said'): 0.0021441817338896615,
#              ('said', 'the'): 0.05960220957815636,
#              ('the', 'trade'): 0.07657992565055761,
#              ('trade', 'dispute'): 0.11920529801324503,
#              ('dispute', 'between'): 0.011374407582938388,
#              ('might', 'also'): 0.00487408610885459,
#              ('also', 'lead'): 0.007662835249042145,
#              ('to', 'pressure'): 0.05,
#              ('pressure', 'on'): 0.009668353007307477,
#              ('on', 'south'): 0.003436426116838488,
#              ('korea', ','): 0.0003082659307429209,
#              (',', 'whose'): 0.6190476190476191,
#              ('whose', 'chief'): 0.009933774834437087,
#              ('chief', 'exports'): 0.0019286403085824494,
#              ('exports', 'are'): 0.008243500317057704,
#              ('are', 'similar'): 0.0189873417721519,
#              ('similar', 'to'): 0.0010118612625779977,
#              ('to', 'those'): 0.05080213903743316,
#              ('those', 'of'): 0.0015216068167985392,
#              ('<s>', 'year'): 0.0392219387755102,
#              ('year', 'south'): 0.010309278350515464,
#              ('korea', 'had'): 0.0017029972752043597,
#              ('dlrs', 'with'): 0.0028099173553719006,
#              ('<s>', '.,'): 0.5069033530571992,
#              ('.,', 'up'): 0.00044306601683650863,
#              ('up', 'from'): 0.03263171005106489,
#              ('dlrs', 'in'): 0.058797814207650276,
#              ('in', '</s>'): 0.022200629475507487,
#              ('<s>', 'malaysia'): 0.04807692307692308,
#              ('malaysia', ','): 0.00036698325088442964,
#              (',', 'trade'): 0.03717472118959108,
#              ('trade', 'officers'): 0.024390243902439025,
#              ('officers', 'and'): 0.00039971220721080823,
#              ('and', 'businessmen'): 0.22,
#              ('businessmen', 'said'): 0.0003477051460361613,
#              ('said', 'tough'): 0.05,
#              ('tough', 'curbs'): 0.023255813953488372,
#              ('curbs', 'against'): 0.0020435967302452314,
#              ('might', 'allow'): 0.009302325581395349,
#              ('allow', 'hard'): 0.007246376811594203,
#              ('hard', '-'): 0.0006247559547051933,
#              ('-', 'hit'): 0.04205607476635514,
#              ('hit', 'producers'): 0.002028397565922921,
#              ('producers', 'of'): 0.00044264925579593867,
#              ('of', 'semiconductors'): 0.06382978723404255,
#              ('semiconductors', 'in'): 0.00047358834244080146,
#              ('in', 'third'): 0.03854389721627409,
#              ('third', 'countries'): 0.026022304832713755,
#              ('countries', 'to'): 0.0016021136657484963,
#              ('to', 'expand'): 0.6462585034013606,
#              ('expand', 'their'): 0.0037230081906180195,
#              ('their', 'sales'): 0.001487357461576599,
#              ('sales', 'to'): 0.0021361515543313284,
#              ('<s>', 'hong'): 0.061224489795918366,
#              ('hong', 'kong'): 0.8641975308641975,
#              ('kong', ','): 0.00027890727067216654,
#              (',', 'where'): 0.4076923076923077,
#              ('where', 'newspapers'): 0.03125,
#              ('newspapers', 'have'): 0.0003266906239790918,
#              ('have', 'alleged'): 0.04,
#              ('alleged', 'japan'): 0.0006574621959237344,
#              ('has', 'been'): 0.35036496350364965,
#              ('been', 'selling'): 0.011673151750972763,
#              ('selling', 'below'): 0.002173913043478261,
#              ('below', '-'): 0.00046856696602889497,
#              ('-', 'cost'): 0.03355704697986577,
#              ('cost', 'semiconductors'): 0.02127659574468085,
#              ('semiconductors', ','): 0.00017615196042452622,
#              (',', 'some'): 0.06832797427652733,
#              ('some', 'electronics'): 0.008547008547008548,
#              ('electronics', 'manufacturers'): 0.0136986301369863,
#              ('manufacturers', 'share'): 0.0004091653027823241,
#              ('share', 'that'): 0.00040972411909314397,
#              ('that', '</s>'): 0.0012357153418812445,
#              ('<s>', 'other'): 0.05111402359108781,
#              ('other', 'businessmen'): 0.02,
#              ('said', 'such'): 0.024844720496894408,
#              ('such', 'a'): 0.004906689033340323,
#              ('a', 'short'): 0.075,
#              ('term', 'commercial'): 0.0034129692832764505,
#              ('commercial', 'advantage'): 0.02,
#              ('advantage', 'would'): 0.00021668472372697725,
#              ('would', 'be'): 0.1756066411238825,
#              ('be', 'outweighed'): 0.3333333333333333,
#              ('outweighed', 'by'): 0.0002875215641173088,
#              ('by', 'further'): 0.003663003663003663,
#              ('further', '</s>'): 0.0009505502629855728,
#              ('<s>', 'to'): 0.02383495418517061,
#              ('to', 'block'): 0.3275862068965517,
#              ('block', '</s>'): 3.168500876618576e-05,
#              ('<s>', 'that'): 0.01953018301010653,
#              ('that', 'is'): 0.012273212379935965,
#              ('is', 'a'): 0.01752988047808765,
#              ('a', 'very'): 0.2386634844868735,
#              ('very', 'short'): 0.011363636363636364,
#              ('term', 'view'): 0.007142857142857143,
#              ('view', ',"'): 0.0011799410029498525,
#              ('said', 'lawrence'): 0.14285714285714285,
#              ('lawrence', 'mills'): 0.015384615384615385,
#              ('mills', ','): 7.339665017688592e-05,
#              (',', 'director'): 0.21171171171171171,
#              ('director', '-'): 0.0006247559547051933,
#              ('-', 'general'): 0.020700636942675158,
#              ('general', 'of'): 0.0005256459912576772,
#              ('the', 'federation'): 0.18055555555555555,
#              ('federation', 'of'): 0.0005809771482321696,
#              ('of', 'hong'): 0.06802721088435375,
#              ('kong', '</s>'): 8.449335670982869e-05,
#              ('<s>', 'if'): 0.13053097345132744,
#              ('the', 'whole'): 0.6082474226804123,
#              ('whole', 'purpose'): 0.02857142857142857,
#              ('purpose', 'is'): 0.00040021344717182497,
#              ('is', 'to'): 0.005368486143122154,
#              ('to', 'prevent'): 0.7256637168141593,
#              ('prevent', 'imports'): 0.0025031289111389237,
#              ('imports', ','): 0.0009247977922287627,
#              (',', 'one'): 0.042395954881369116,
#              ('one', 'day'): 0.02329450915141431,
#              ('day', 'it'): 0.00021980437410704473,
#              ('will', 'be'): 0.25638569604086847,
#              ('be', 'extended'): 0.12195121951219512,
#              ('extended', 'to'): 0.0005340378885828321,
#              ('to', 'other'): 0.0399737876802097,
#              ('other', '</s>'): 0.0019327855347373313,
#              ('<s>', 'more'): 0.012373453318335208,
#              ('more', 'serious'): 0.01834862385321101,
#              ('serious', 'for'): 7.583801001061732e-05,
#              ('for', 'hong'): 0.013605442176870748,
#              ('kong', 'is'): 0.00026680896478121667,
#              ('is', 'the'): 0.00525853059734917,
#              ('the', 'disadvantage'): 0.16666666666666666,
#              ('disadvantage', 'of'): 2.7665578487246167e-05,
#              ('of', 'action'): 0.03836317135549872,
#              ('action', 'restraining'): 0.0625,
#              ('restraining', 'trade'): 0.0003717472118959108,
#              ('trade', ',"'): 0.0017699115044247787,
#              (',"', 'he'): 0.25649867374005303,
#              ('he', '</s>'): 0.016465642888827865,
#              ('year', 'was'): 0.0072992700729927005,
#              ('was', 'hong'): 0.006802721088435374,
#              ('kong', "'"): 0.001446393057313325,
#              ('s', 'biggest'): 0.32978723404255317,
#              ('biggest', 'export'): 0.0009950248756218905,
#              ('export', 'market'): 0.0024009603841536613,
#              ('market', ','): 0.002906507347004683,
#              (',', 'accounting'): 0.05511811023622047,
#              ('accounting', 'for'): 0.0021993022903079025,
#              ('for', 'over'): 0.009915014164305949,
#              ('over', '30'): 0.007850834151128557,
#              ('30', 'pct'): 0.014852050725465554,
#              ('of', 'domestically'): 0.2,
#              ('domestically', 'produced'): 0.031578947368421054,
#              ('produced', '</s>'): 0.0001478633742422002,
#              ('<s>', 'australian'): 0.04020100502512563,
#              ('australian', 'government'): 0.004481434058898848,
#              ('government', 'is'): 0.006536819637139808,
#              ('is', 'awaiting'): 0.10714285714285714,
#              ('awaiting', 'the'): 6.635369838926397e-05,
#              ('the', 'outcome'): 0.5813953488372093,
#              ('outcome', 'of'): 0.0006916394621811542,
#              ('of', 'trade'): 0.041263940520446095,
#              ('trade', 'talks'): 0.054602184087363496,
#              ('talks', 'between'): 0.016113744075829384,
#              ('japan', 'with'): 0.001322314049586777,
#              ('with', 'interest'): 0.0039494470774091624,
#              ('interest', 'and'): 0.0007994244144216165,
#              ('and', 'concern'): 0.012121212121212121,
#              ('concern', ','): 0.00024954861060141214,
#              (',', 'industry'): 0.07482993197278912,
#              ('industry', 'minister'): 0.019337016574585635,
#              ('minister', 'john'): 0.08333333333333333,
#              ('john', 'button'): 0.5,
#              ('button', 'said'): 5.795085767269355e-05,
#              ('said', 'in'): 0.026083788706739528,
#              ('in', 'canberra'): 1.0,
#              ('canberra', 'last'): 0.00033057851239669424,
#              ('last', '</s>'): 0.007044633615681967,
#              ('<s>', 'this'): 0.07717678100263853,
#              ('this', 'kind'): 0.11864406779661017,
#              ('kind', 'of'): 0.0011066231394898467,
#              ('of', 'deterioration'): 0.03225806451612903,
#              ('deterioration', 'in'): 0.0009107468123861566,
#              ('in', 'trade'): 0.018215613382899627,
#              ('trade', 'relations'): 0.21794871794871795,
#              ('relations', 'between'): 0.01042654028436019,
#              ('between', 'two'): 0.006462035541195477,
#              ('two', 'countries'): 0.06567534076827757,
#              ('countries', 'which'): 0.0021971985718209283,
#              ('which', 'are'): 0.027266962587190868,
#              ('are', 'major'): 0.0031645569620253164,
#              ('major', 'trading'): 0.027777777777777776,
#              ('trading', 'partners'): 0.14232209737827714,
#              ('partners', 'of'): 8.299673546173851e-05,
#              ('of', 'ours'): 0.5,
#              ('ours', 'is'): 0.00013340448239060833,
#              ('very', 'serious'): 0.14678899082568808,
#              ('serious', 'matter'): 0.016129032258064516,
#              ('matter', ',"'): 0.0014749262536873156,
#              (',"', 'button'): 0.5,
#              ('button', '</s>'): 1.0561669588728586e-05,
#              ('said', 'australia'): 0.017241379310344827,
#              ('australia', "'"): 0.004971976134514554,
#              ('s', 'concerns'): 0.08888888888888889,
#              ('concerns', 'centred'): 0.1,
#              ('centred', 'on'): 0.0008993816750983699,
#              ('on', 'coal'): 0.009900990099009901,
#              ('coal', 'and'): 0.0007994244144216165,
#              ('and', 'beef'): 0.05641025641025641,
#              ('beef', ','): 0.0003082659307429209,
#              (',', 'australia'): 0.0603448275862069,
#              ('s', 'two'): 0.006462035541195477,
#              ('two', 'largest'): 0.02925531914893617,
#              ('largest', 'exports'): 0.0009643201542912247,
#              ('exports', 'to'): 0.00421608859407499,
#              ('to', 'japan'): 0.045364891518737675,
#              ('japan', 'and'): 0.00435686305859781,
#              ('and', 'also'): 0.012997562956945572,
#              ('also', 'significant'): 0.005681818181818182,
#              ('significant', '</s>'): 5.280834794364293e-05,
#              ('to', 'that'): 0.004916689429117728,
#              ('.-', 'japanese'): 0.02242152466367713,
#              ('japanese', 'diplomatic'): 0.04,
#              ('diplomatic', 'manoeuvres'): 0.3333333333333333,
#              ('manoeuvres', 'to'): 2.8107257293833266e-05,
#              ('to', 'solve'): 0.7435897435897436,
#              ('solve', 'the'): 0.00028200321815437186,
#              ('trade', 'stand'): 0.029850746268656716,
#              ('stand', '-'): 0.00031237797735259666,
#              ('-', 'off'): 0.0912621359223301,
#              ('off', '</s>'): 0.0008132485583321012,
#              ('<s>', "'"): 0.07982281685047912,
#              ('s', 'ruling'): 0.125,
#              ('ruling', 'liberal'): 0.3939393939393939,
#              ('liberal', 'democratic'): 0.3617021276595745,
#              ('democratic', 'party'): 0.1981981981981982,
#              ('party', 'yesterday'): 0.001968503937007874,
#              ('yesterday', 'outlined'): 0.030303030303030304,
#              ('outlined', 'a'): 0.00012581253931641853,
#              ('a', 'package'): 0.1773049645390071,
#              ('package', 'of'): 0.0008023017761301388,
#              ('of', 'economic'): 0.0709812108559499,
#              ('economic', 'measures'): 0.018726591760299626,
#              ('measures', 'to'): 0.001686435437629996,
#              ('to', 'boost'): 0.5203619909502263,
#              ('boost', 'the'): 0.0003483569165436358,
#              ('the', 'japanese'): 0.22085201793721973,
#              ('japanese', '</s>'): 0.000612576836146258,
#              ('<s>', 'measures'): 0.04868913857677903,
#              ('measures', 'proposed'): 0.0018552875695732839,
#              ('proposed', 'include'): 0.0023148148148148147,
#              ('include', 'a'): 0.0020130006290626965,
#              ('a', 'large'): 0.2565597667638484,
#              ('large', 'supplementary'): 0.375,
#              ('supplementary', 'budget'): 0.009029345372460496,
#              ('budget', 'and'): 0.00043968342793188905,
#              ('and', 'record'): 0.004694835680751174,
#              ('record', 'public'): 0.002331002331002331,
#              ('public', 'works'): 0.34210526315789475,
#              ('works', 'spending'): 0.008547008547008548,
#              ('spending', 'in'): 0.000692167577413479,
#              ('the', 'first'): 0.47660311958405543,
#              ('first', 'half'): 0.1840277777777778,
#              ('half', 'of'): 0.005616112432910972,
#              ('the', 'financial'): 0.11716937354988399,
#              ('financial', '</s>'): 0.0009505502629855728,
#              ('<s>', 'also'): 0.23273761169780666,
#              ('also', 'call'): 0.005847953216374269,
#              ('call', 'for'): 0.0039435765205521,
#              ('for', 'stepped'): 0.1111111111111111,
#              ('stepped', '-'): 0.0003904724716907458,
#              ('-', 'up'): 0.05050952591936198,
#              ('up', 'spending'): 0.004273504273504274,
#              ('spending', 'as'): 0.00046728971962616824,
#              ('as', 'an'): 0.029331514324693043,
#              ('an', 'emergency'): 0.3076923076923077,
#              ('emergency', 'measure'): 0.022388059701492536,
#              ('measure', 'to'): 0.00022485805835066613,
#              ('to', 'stimulate'): 0.7976190476190477,
#              ('stimulate', 'the'): 0.00028200321815437186,
#              ('the', 'economy'): 0.43776824034334766,
#              ('economy', 'despite'): 0.003861003861003861,
#              ('despite', 'prime'): 0.002857142857142857,
#              ('prime', 'minister'): 0.1574585635359116,
#              ('minister', 'yasuhiro'): 0.975609756097561,
#              ('yasuhiro', 'nakasone'): 0.3958333333333333,
#              ('nakasone', "'"): 0.0017175917555595733,
#              ('s', 'avowed'): 1.0,
#              ('avowed', 'fiscal'): 0.0019267822736030828,
#              ('fiscal', 'reform'): 0.009259259259259259,
#              ('reform', '</s>'): 6.337001753237152e-05,
#              ('<s>', 'representative'): 0.5583333333333333,
#              ('representative', 'michael'): 0.08450704225352113,
#              ('michael', 'smith'): 0.08571428571428572,
#              ('smith', 'and'): 0.00019985610360540411,
#              ('and', 'makoto'): 0.2,
#              ('makoto', 'kuroda'): 0.5,
#              ('kuroda', ','): 2.935866007075437e-05,
#              (',', 'japan'): 0.07232084155161078,
#              ('s', 'deputy'): 0.10975609756097561,
#              ('deputy', 'minister'): 0.0027624309392265192,
#              ('minister', 'of'): 0.0009129640900791236,
#              ('of', 'international'): 0.05521472392638037,
#              ('international', 'trade'): 0.025278810408921933,
#              ('trade', 'and'): 0.004756575265808618,
#              ('and', 'industry'): 0.10430839002267574,
#              ('industry', '('): 0.01030141167493323,
#              ('(', 'miti'): 0.2948717948717949,
#              ('miti', '),'): 0.00904977375565611,
#              ('),', 'are'): 0.0012682308180088776,
#              ('are', 'due'): 0.04225352112676056,
#              ('due', 'to'): 0.018382146270166957,
#              ('to', 'meet'): 0.597972972972973,
#              ('meet', 'in'): 0.0007650273224043716,
#              ('in', 'washington'): 0.271523178807947,
#              ('washington', 'this'): 0.0013192612137203166,
#              ('this', 'week'): 0.16655052264808362,
#              ('week', 'in'): 0.0009107468123861566,
#              ('in', 'an'): 0.06116416552978627,
#              ('an', 'effort'): 0.4262295081967213,
#              ('effort', 'to'): 0.0026420821856203273,
#              ('to', 'end'): 0.11290322580645161,
#              ('end', 'the'): 0.00041471061493289984,
#              ('<s>', 'daily'): 0.06808510638297872,
#              ('daily', 'says'): 0.007042253521126761,
#              ('says', 'vermin'): 0.5,
#              ('vermin', 'eat'): 0.2,
#              ('eat', '7'): 0.0012391573729863693,
#              ('7', '-'): 0.01116751269035533,
#              ('-', '12'): 0.019230769230769232,
#              ('12', 'pct'): 0.007768764994858905,
#              ('pct', 'grain'): 0.0017035775127768314,
#              ('grain', 'stocks'): 0.012396694214876033,
#              ('stocks', 'a'): 4.1937513105472846e-05,
#              ('a', 'survey'): 0.11224489795918367,
#              ('survey', 'of'): 0.00047031483428318485,
#              ('of', '19'): 0.05660377358490566,
#              ('19', 'provinces'): 0.041666666666666664,
#              ('provinces', 'and'): 0.00011991366216324247,
#              ('and', 'seven'): 0.030357142857142857,
#              ('seven', 'cities'): 0.13333333333333333,
#              ('cities', 'showed'): 0.004166666666666667,
#              ('showed', 'vermin'): 0.5,
#              ('vermin', 'consume'): 0.25,
#              ('consume', 'between'): 0.0009478672985781991,
#              ('between', 'seven'): 0.007142857142857143,
#              ('seven', 'and'): 0.00011991366216324247,
#              ('and', '12'): 0.04807692307692308,
#              ('of', 'china'): 0.08184143222506395,
#              ('china', "'"): 0.006689567890074128,
#              ('s', 'grain'): 0.028960817717206135,
#              ('stocks', ','): 0.0007780044918749908,
#              (',', 'the'): 0.07134681419305608,
#              ('the', 'china'): 0.05115089514066496,
#              ('china', 'daily'): 0.1148936170212766,
#              ('daily', '</s>'): 0.00024291840054075747,
#              ('also', 'said'): 0.03291608715808994,
#              ('that', 'each'): 0.006772009029345372,
#              ('each', 'year'): 0.002072704081632653,
#              ('year', '</s>'): 0.00418242115713652,
#              ('<s>', 'mln'): 0.6723868050321757,
#              ('mln', 'tonnes'): 0.31592803861342694,
#              ('tonnes', ','): 0.0057396180438324795,
#              (',', 'or'): 0.33483290488431877,
#              ('or', '25'): 0.01589825119236884,
#              ('25', 'pct'): 0.014852050725465554,
#              ('pct', ','): 0.010172775714516389,
#              (',', 'of'): 0.004537154871908372,
#              ('s', 'fruit'): 0.04,
#              ('fruit', 'output'): 0.0015873015873015873,
#              ('output', 'are'): 0.0003170577045022194,
#              ('are', 'left'): 0.014388489208633094,
#              ('left', 'to'): 0.00011242902917533307,
#              ('to', 'rot'): 0.125,
#              ('rot', ','): 2.935866007075437e-05,
#              (',', 'and'): 0.07242785194659845,
#              ('and', '</s>'): 0.016011491096512537,
#              ('or', 'up'): 0.001329198050509526,
#              ('up', 'to'): 0.013660127044802968,
#              ('to', '30'): 0.0647693817468106,
#              ('of', 'its'): 0.1553291104378959,
#              ('its', '</s>'): 0.00410848947001542,
#              ('<s>', 'paper'): 0.2608695652173913,
#              ('paper', 'blamed'): 0.03333333333333333,
#              ('blamed', 'the'): 0.0001990610951677919,
#              ('the', 'waste'): 0.04477611940298507,
#              ('waste', 'on'): 0.00011242270938729624,
#              ('on', 'inadequate'): 0.038461538461538464,
#              ('inadequate', 'storage'): 0.011494252873563218,
#              ('storage', 'and'): 0.0003197697657686466,
#              ('and', 'bad'): 0.057971014492753624,
#              ('bad', 'preservation'): 0.2,
#              ('preservation', '</s>'): 1.0561669588728586e-05,
#              ('the', 'government'): 0.4180537772087068,
#              ('government', 'had'): 0.015667574931880108,
#              ('had', 'launched'): 0.03571428571428571,
#              ('launched', 'a'): 0.0013839379324806038,
#              ('a', 'national'): 0.034047919293820936,
#              ('national', 'programme'): 0.023809523809523808,
#              ('programme', 'to'): 8.43217718814998e-05,
#              ('to', 'reduce'): 0.5356200527704486,
#              ('reduce', 'waste'): 0.014925373134328358,
#              ('waste', ','): 2.935866007075437e-05,
#              (',', 'calling'): 0.09523809523809523,
#              ('calling', 'for'): 0.0020476262702866675,
#              ('for', 'improved'): 0.016042780748663103,
#              ('improved', 'technology'): 0.016483516483516484,
#              ('technology', 'in'): 0.00014571948998178506,
#              ('in', 'storage'): 0.034482758620689655,
#              ('and', 'preservation'): 0.2,
#              ('preservation', ','): 1.4679330035377185e-05,
#              ('and', 'greater'): 0.07586206896551724,
#              ('greater', 'production'): 0.0015071590052750565,
#              ('production', 'of'): 0.002628229956288386,
#              ('paper', 'gave'): 0.0048543689320388345,
#              ('gave', 'no'): 0.09239940387481371,
#              ('no', 'further'): 0.050061050061050064,
#              ('to', 'revise'): 0.6,
#              ('revise', 'long'): 0.0016778523489932886,
#              ('term', 'energy'): 0.004081632653061225,
#              ('energy', 'demand'): 0.0049833887043189366,
#              ('demand', 'downwards'): 0.05555555555555555,
#              ('downwards', 'the'): 4.976527379194798e-05,
#              ('the', 'ministry'): 0.2003780718336484,
#              ('ministry', 'of'): 0.001964256072594478,
#              ('miti', ')'): 0.009433962264150943,
#              (')', 'will'): 0.007347915242652085,
#              ('will', 'revise'): 0.2,
#              ('revise', 'its'): 0.0006885155604516662,
#              ('its', 'long'): 0.030201342281879196,
#              ('energy', 'supply'): 0.008561643835616438,
#              ('supply', '/'): 0.007168458781362007,
#              ('/', 'demand'): 0.053156146179401995,
#              ('demand', 'outlook'): 0.02097902097902098,
#              ('outlook', 'by'): 0.0001437607820586544,
#              ('by', 'august'): 0.02304147465437788,
#              ('august', 'to'): 0.0001686435437629996,
#              ('meet', 'a'): 0.0002935625917383099,
#              ('a', 'forecast'): 0.025490196078431372,
#              ('forecast', 'downtrend'): 0.25,
#              ('downtrend', 'in'): 0.0001092896174863388,
#              ('in', 'japanese'): 0.013452914798206279,
#              ('japanese', 'energy'): 0.0020408163265306124,
#              ('demand', ','): 0.001027553102476403,
#              (',', 'ministry'): 0.026465028355387523,
#              ('ministry', 'officials'): 0.054987212276214836,
#              ('<s>', 'is'): 0.06643543223052295,
#              ('is', 'expected'): 0.36343283582089553,
#              ('expected', 'to'): 0.023413345325763113,
#              ('to', 'lower'): 0.09741060419235512,
#              ('lower', 'the'): 0.0002985916427516879,
#              ('the', 'projection'): 0.15789473684210525,
#              ('projection', 'for'): 0.00022751403003185196,
#              ('for', 'primary'): 0.013888888888888888,
#              ('primary', 'energy'): 0.0020408163265306124,
#              ('energy', 'supplies'): 0.005714285714285714,
#              ('supplies', 'in'): 0.0004007285974499089,
#              ('the', 'year'): 0.09422831632653061,
#              ('year', '2000'): 0.4827586206896552,
#              ('2000', 'to'): 2.8107257293833266e-05,
#              ('to', '550'): 0.07547169811320754,
#              ('550', 'mln'): 0.0008696156298915879,
#              ('mln', 'kilolitres'): 1.0,
#              ('kilolitres', '('): 0.00038153376573826786,
#              ('(', 'kl'): 0.5,
#              ('kl', ')'): 0.0005241090146750524,
#              (')', 'from'): 0.0032382613027774317,
#              ('from', '600'): 0.023972602739726026,
#              ('600', 'mln'): 0.0026668212650008695,
#              ('mln', ','): 0.0030239419872877,
#              (',', 'they'): 0.25035095928872253,
#              ('they', '</s>'): 0.004678819627806764,
#              ('<s>', 'decision'): 0.08284023668639054,
#              ('decision', 'follows'): 0.016666666666666666,
#              ('follows', 'the'): 0.00018247267057047592,
#              ('the', 'emergence'): 0.6,
#              ('emergence', 'of'): 0.00011066231394898467,
#              ('of', 'structural'): 0.125,
#              ('structural', 'changes'): 0.024489795918367346,
#              ('changes', 'in'): 0.0034972677595628415,
#              ('japanese', 'industry'): 0.003401360544217687,
#              ('industry', 'following'): 0.008241758241758242,
#              ('following', 'the'): 0.0017749614319128113,
#              ('the', 'rise'): 0.05048076923076923,
#              ('rise', 'in'): 0.017777777777777778,
#              ('the', 'value'): 0.2578740157480315,
#              ('value', 'of'): 0.0077463619764289275,
#              ('the', 'yen'): 0.2643979057591623,
#              ('yen', 'and'): 0.0010792229594691822,
#              ('and', 'a'): 0.02403019500943594,
#              ('a', 'decline'): 0.14640198511166252,
#              ('decline', 'in'): 0.006848816029143898,
#              ('in', 'domestic'): 0.06451612903225806,
#              ('domestic', 'electric'): 0.007352941176470588,
#              ('electric', 'power'): 0.05,
#              ('power', '</s>'): 9.505502629855728e-05,
#              ('is', 'planning'): 0.12173913043478261,
#              ('planning', 'to'): 0.0005902524031704986,
#              ('to', 'work'): 0.3143939393939394,
#              ('work', 'out'): 0.02997275204359673,
#              ('out', 'a'): 0.0020130006290626965,
#              ('a', 'revised'): 0.26358695652173914,
#              ('revised', 'energy'): 0.0020408163265306124,
#              ('outlook', 'through'): 0.0014084507042253522,
#              ('through', 'deliberations'): 0.2,
#              ('deliberations', 'of'): 2.7665578487246167e-05,
#              ('of', 'committee'): 0.0024154589371980675,
#              ('committee', 'meetings'): 0.010869565217391304,
#              ('meetings', 'of'): 0.0006363083052066618,
#              ('the', 'agency'): 0.2090032154340836,
#              ('agency', 'of'): 8.299673546173851e-05,
#              ('of', 'natural'): 0.14652014652014653,
#              ('natural', 'resources'): 0.028125,
#              ('resources', 'and'): 0.0006395395315372932,
#              ('and', 'energy'): 0.0673469387755102,
#              ('energy', ','): 0.00016147263038914905,
#              ('the', 'officials'): 0.07033248081841433,
#              ('said', 'miti'): 0.0641025641025641,
#              ('miti', 'will'): 0.00017088174982911826,
#              ('will', 'also'): 0.05077173030056864,
#              ('also', 'review'): 0.005649717514124294,
#              ('review', 'the'): 0.0004312990395302158,
#              ('the', 'breakdown'): 0.2564102564102564,
#              ('breakdown', 'of'): 0.0005809771482321696,
#              ('of', 'energy'): 0.053061224489795916,
#              ('supply', 'sources'): 0.0035885167464114833,
#              ('sources', ','): 0.00027890727067216654,
#              (',', 'including'): 0.7131931166347992,
#              ('including', 'oil'): 0.0009910802775024777,
#              ('oil', ','): 0.001746840274209885,
#              (',', 'nuclear'): 0.045454545454545456,
#              ('nuclear', ','): 1.4679330035377185e-05,
#              (',', 'coal'): 0.07920792079207921,
#              ('and', 'natural'): 0.17216117216117216,
#              ('natural', '</s>'): 0.00015842504383092878,
#              ('<s>', 'energy'): 0.09795918367346938,
#              ('energy', 'provided'): 0.006535947712418301,
#              ('provided', 'the'): 0.0008625980790604316,
#              ('the', 'bulk'): 0.2808988764044944,
#              ('bulk', 'of'): 0.0007469706191556466,
#              ('of', 'japan'): 0.16962524654832348,
#              ('s', 'electric'): 0.007352941176470588,
#              ('power', 'in'): 0.00029143897996357013,
#              ('the', 'fiscal'): 0.1348747591522158,
#              ('fiscal', 'year'): 0.025669642857142856,
#              ('year', 'ended'): 0.19858156028368795,
#              ('ended', 'march'): 0.08289855072463768,
#              ('march', '31'): 0.23098859315589354,
#              ('31', ','): 0.00443315767068391,
#              (',', 'supplying'): 0.06666666666666667,
#              ('supplying', 'an'): 0.00022737608003638017,
#              ('an', 'estimated'): 0.18050541516245489,
#              ('estimated', '27'): 0.0034965034965034965,
#              ('27', 'pct'): 0.002970410145093111,
#              ('pct', 'on'): 0.013603147835862844,
#              ('on', 'a'): 0.02180750681484588,
#              ('a', 'kilowatt'): 0.3333333333333333,
#              ('kilowatt', '/'): 0.00023894862604540023,
#              ('/', 'hour'): 0.02702702702702703,
#              ('hour', 'basis'): 0.003424657534246575,
#              ('basis', ','): 0.001027553102476403,
#              (',', 'followed'): 0.11818181818181818,
#              ('followed', 'by'): 0.005750431282346176,
#              ('by', 'oil'): 0.003303600925008259,
#              ('oil', '('): 0.005723006486074018,
#              ('(', '23'): 0.006688963210702341,
#              ('23', 'pct'): 0.0035416428653033244,
#              ('pct', ')'): 0.007861635220125786,
#              (')', 'and'): 0.0036373810856183547,
#              ('and', 'liquefied'): 0.25,
#              ('liquefied', 'natural'): 0.02197802197802198,
#              ('natural', 'gas'): 0.24771838331160365,
#              ('gas', '('): 0.0015261350629530714,
#              ('(', '21'): 0.004347826086956522,
#              ('21', 'pct'): 0.0023991774248828973,
#              ('pct', '),'): 0.01583710407239819,
#              ('),', 'they'): 0.0028076743097800653,
#              ('<s>', 'trade'): 0.05910780669144981,
#              ('trade', 'deficit'): 0.2503242542153048,
#              ('deficit', 'widens'): 0.6,
#              ('widens', 'in'): 0.00036429872495446266,
#              ('in', 'first'): 0.02484113229347198,
#              ('first', 'quarter'): 0.29396984924623115,
#              ('quarter', 'thailand'): 0.011363636363636364,
#              ('thailand', "'"): 0.0016271921894774905,
#              ('deficit', 'widened'): 0.3333333333333333,
#              ('widened', 'to'): 0.0007026814323458317,
#              ('to', '</s>'): 0.03367060264886673,
#              ('billion', 'baht'): 0.9,
#              ('baht', 'in'): 0.0002185792349726776,
#              ('quarter', 'of'): 0.005588446854423726,
#              ('of', '1987'): 0.07290015847860538,
#              ('1987', 'from'): 0.006102877070619006,
#              ('billion', 'a'): 0.003019500943594045,
#              ('a', 'year'): 0.12292729591836735,
#              ('year', 'ago'): 0.3448275862068966,
#              ('ago', ','): 0.0015266503236792274,
#              ('the', 'business'): 0.07253886010362694,
#              ('business', 'economics'): 0.023255813953488372,
#              ('economics', 'department'): 0.0032967032967032967,
#              ('department', '</s>'): 0.0028516507889567184,
#              ('said', 'janunary'): 1.0,
#              ('janunary', '/'): 0.00023894862604540023,
#              ('/', 'march'): 0.007536231884057971,
#              ('march', 'imports'): 0.0012515644555694619,
#              ('imports', 'rose'): 0.026765799256505577,
#              ('rose', 'to'): 0.01023104165495531,
#              ('baht', 'from'): 0.0008718395815170009,
#              ('s', 'improved'): 0.016042780748663103,
#              ('improved', 'business'): 0.0012953367875647669,
#              ('business', 'climate'): 0.07407407407407407,
#              ('climate', 'this'): 0.00032981530343007914,
#              ('this', 'year'): 0.13137755102040816,
#              ('year', 'resulted'): 0.01098901098901099,
#              ('resulted', 'in'): 0.001930783242258652,
#              ('in', 'a'): 0.0506605158314112,
#              ('a', '27'): 0.03496503496503497,
#              ('pct', 'increase'): 0.11280214861235452,
#              ('increase', 'in'): 0.012604735883424409,
#              ('in', 'imports'): 0.02127659574468085,
#              ('of', 'raw'): 0.11702127659574468,
#              ('raw', 'materials'): 0.20175438596491227,
#              ('materials', 'and'): 0.0005196258693740507,
#              ('and', 'semi'): 0.11538461538461539,
#              ('semi', '-'): 0.0040609137055837565,
#              ('-', 'finished'): 0.18181818181818182,
#              ('finished', '</s>'): 6.337001753237152e-05,
#              ('<s>', 'country'): 0.0502092050209205,
#              ('country', "'"): 0.01708551798951365,
#              ('s', 'oil'): 0.020482325735051207,
#              ('oil', 'import'): 0.09336609336609336,
#              ('import', 'bill'): 0.009345794392523364,
#              ('bill', ','): 0.00046973856113206994,
#              (',', 'however'): 0.8125,
#              ('however', ','): 0.003346887248065998,
#              (',', 'fell'): 0.06605922551252848,
#              ('fell', '23'): 0.006688963210702341,
#              ('pct', 'in'): 0.04542805100182149,
#              ('quarter', 'due'): 0.005868544600938967,
#              ('lower', 'oil'): 0.005946481665014866,
#              ('oil', '</s>'): 0.0016053737774867451,
#              ('<s>', 'department'): 0.4021978021978022,
#              ('department', 'said'): 0.007591562355122856,
#              ('said', 'first'): 0.012709416522241479,
#              ('quarter', 'exports'): 0.003857280617164899,
#              ('exports', 'expanded'): 0.03571428571428571,
#              ('expanded', 'to'): 0.00011242902917533307,
#              ('<s>', 'growth'): 0.03768115942028986,
#              ...})

# %% [markdown]
# #### using markov's assumption on chain rule of probability

# %% [markdown]
# #### prediction
# n = how many words has to be predicted<br>
# grams=how many grams does user wants us to predict the next word<br>

# %%
def predict(ip):
    ip=ip.split(" ")
    if len(ip)==2:
        for i in range(10):
            # print(ip)
            temp=[0]
            predictor=0.0
            for key,value in biprob.items():
                try:
                    if key[0]==ip[-1]:#checking first word is matching with the last word of our ip
                        if biprob[key]>predictor:
                            if key[-1]=="</s>":
                                break
                            else:
                                predictor=biprob[key]
                                temp[0]=(key,value)
                except TypeError:
                    pass
            try:
                ip.append(temp[0][0][-1])
            except TypeError: #if this occurs--> </s> is reached
                break #this will the first loop
                
        # print(ip)
        # print(temp)
        return " ".join(ip)
    if len(ip)==3:
        for i in range(12):
            # print(ip)
            temp=[0]
            predictor=0.0
            for key,value in triprob.items():
                try:
                    if key[0:2]==tuple(ip[-2:]):
                        # print("here",key[0:2],ip[-2:])
                        if triprob[key]>predictor:
                            if key[-1]=="</s>":
                                break
                            else:
                                predictor=triprob[key]
                                temp[0]=(key,value)
                except TypeError:
                    pass
            try:
                ip.append(temp[0][0][-1])
            except TypeError: #if this occurs--> </s> is reached
                break #this will the first loop
        return " ".join(ip)
    if len(ip)==4:
        for i in range(16): #random threshold values
            # print(ip)
            temp=[0]
            predictor=0.0
            for key,value in fourprob.items():
                try:
                    # print("in",key[0:3],tuple(ip[-3:]))
                    if key[0:3]==tuple(ip[-3:]):
                        print("in",key[0:3],tuple(ip[-3:]))
                        if fourprob[key]>predictor:
                            if key[-1]=="</s>":
                                break
                            else:
                                predictor=fourprob[key]
                                temp[0]=(key,value)
                except TypeError:
                    print("type error")
                    pass
            try:
                ip.append(temp[0][0][-1])
            except TypeError: #if this occurs--> </s> is reached
                break #this will the first loop
        return " ".join(ip)
    if len(ip)>=5:
        print("in")
        for i in range(3):
            # print(ip)
            temp=[0]
            predictor=0.0
            for key,value in fiveprob.items():
                try:
                    print(tuple(ip[-4:]))
                    if key[0:4]==tuple(ip[-4:]):
                        print(key,value)
                        if fiveprob[key]>predictor:

                            if key[-1]=="</s>":
                                print(key,value)
                                break
                            else:
                                predictor=fiveprob[key]
                                temp[0]=(key,value)
                except TypeError:
                    pass
            try:
                ip.append(temp[0][0][-1])
            except TypeError: #if this occurs--> </s> is reached
                break #this will the first loop
        return " ".join(ip)

# %%
print(predict("exporters fear tighter")) #predicting the next two words using bigram
print(predict("exporters fear")) #predicting the next two words using bigram
# Out:
# exporters fear tighter policy to deprive iranian rulers of oil equivalent at a proper level
# exporters fear tighter monetary

# %%
print(predict("exporters fear damage from"))
# Out:
# in ('fear', 'damage', 'from') ('fear', 'damage', 'from')
# exporters fear damage from

# %%
a=('fear', 'damage', 'from') 
b=('fears', 'damage', 'from')
if a==b:
    print("hey")

# %%
reuters.words('test/14828')
# Out:
# ['CHINA', 'DAILY', 'SAYS', 'VERMIN', 'EAT', '7', '-', ...]

# %%
def predict(ip):

# %%
reuters.words("test/1000")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda\envs\machine_learning\lib\site-packages\nltk\data.py in __init__(self, zipfile, entry)
#     402             try:
# --> 403                 zipfile.getinfo(entry)
#     404             except Exception as e:
#
# C:\anaconda\envs\machine_learning\lib\zipfile.py in getinfo(self, name)
#    1440         if info is None:
# -> 1441             raise KeyError(
#    1442                 'There is no item named %r in the archive' % name)
#
# KeyError: "There is no item named 'reuters/test/1000' in the archive"
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-179-f1850c4b415b> in <module>
# ----> 1 reuters.words("test/1000")
#
# C:\anaconda\envs\machine_learning\lib\site-packages\nltk\corpus\reader\api.py in words(self, fileids, categories)
#     403
#     404     def words(self, fileids=None, categories=None):
# --> 405         return super().words(self._resolve(fileids, categories))
#     406
#     407     def sents(self, fileids=None, categories=None):
#
# C:\anaconda\envs\machine_learning\lib\site-packages\nltk\corpus\reader\plaintext.py in words(self, fileids)
#      74             [
#      75                 self.CorpusView(path, self._read_word_block, encoding=enc)
# ---> 76                 for (path, enc, fileid) in self.abspaths(fileids, True, True)
#      77             ]
#      78         )
#
# C:\anaconda\envs\machine_learning\lib\site-packages\nltk\corpus\reader\api.py in abspaths(self, fileids, include_encoding, include_fileid)
#     192             fileids = [fileids]
#     193
# --> 194         paths = [self._root.join(f) for f in fileids]
#     195
#     196         if include_encoding and include_fileid:
#
# C:\anaconda\envs\machine_learning\lib\site-packages\nltk\corpus\reader\api.py in <listcomp>(.0)
#     192             fileids = [fileids]
#     193
# --> 194         paths = [self._root.join(f) for f in fileids]
#     195
#     196         if include_encoding and include_fileid:
#
# C:\anaconda\envs\machine_learning\lib\site-packages\nltk\data.py in join(self, fileid)
#     449     def join(self, fileid):
#     450         entry = f"{self._entry}/{fileid}"
# --> 451         return ZipFilePathPointer(self._zipfile, entry)
#     452
#     453     def __repr__(self):
#
# C:\anaconda\envs\machine_learning\lib\site-packages\nltk\compat.py in _decorator(*args, **kwargs)
#      39     def _decorator(*args, **kwargs):
#      40         args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41         return init_func(*args, **kwargs)
#      42
#      43     return wraps(init_func)(_decorator)
#
# C:\anaconda\envs\machine_learning\lib\site-packages\nltk\data.py in __init__(self, zipfile, entry)
#     413                 else:
#     414                     # Otherwise, complain.
# --> 415                     raise OSError(
#     416                         f"Zipfile {zipfile.filename!r} does not contain {entry!r}"
#     417                     ) from e
#
# OSError: Zipfile 'C:\\Users\\rbw19\\AppData\\Roaming\\nltk_data\\corpora\\reuters.zip' does not contain 'reuters/test/1000'

# %%
ip=['exporters', 'fear']
temp=('fear', 'tighter')
new_temp=[]
for
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-8edfb8b2b671> in <module>
#       2 temp=('fear', 'tighter')
#       3 print(ip.reverse())
# ----> 4 ip=set(ip.reverse())
#       5 # print(ip)
#       6 # temp=set(temp)
#
# TypeError: 'NoneType' object is not iterable
